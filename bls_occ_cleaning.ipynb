# %%
import pandas as pd

# %%
df = pd.read_csv('bls_occupation_allocc.csv')

# %%
df
# Out:
#      Table 1.2 Occupational projections, 2023–33, and worker characteristics, 2023 (Numbers in thousands)  \
# 0                 2023 National Employment Matrix title
# 1                                Total, all occupations
# 2                                Management occupations
# 3                                        Top executives
# 4                                      Chief executives
# ...                                                 ...
# 1113                 Material moving workers, all other
# 1114                                         Footnotes:
# 1115  [1] Data are from the Occupational Employment ...
# 1116  Note: Data is unavailable for values denoted w...
# 1117  Source: Employment Projections program, U.S. B...
#
#                                 Unnamed: 1       Unnamed: 2        Unnamed: 3  \
# 0     2023 National Employment Matrix code  Occupation type  Employment, 2023
# 1                                  00-0000          Summary         167,849.8
# ...
